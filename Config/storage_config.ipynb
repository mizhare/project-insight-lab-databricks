# %% [markdown]
# ### 1. Obtenção de secrets keys para acesso aos storages

# %%
# %run ./secrets_config

# %% [markdown]
# ### 2. Definição de storages (input e output)

# %%
storage_input = "landingbeca2026jan"
storage_account  = "storageinsightlab"
container = "bronze"
container_silver = "silver"

# %% [markdown]
# ### 3. Setando configuração de acesso utilizando a key

# %%
spark.conf.set(f"fs.azure.account.key.{storage_account}.dfs.core.windows.net",bronze_storage_key)

# %%
spark.conf.set(f"fs.azure.account.key.{storage_input}.dfs.core.windows.net", input_storage_key)

# %% [markdown]
# ### 4. Definição dos paths

# %%
# Input Path
cnpj_path = f"abfss://cnpj@{storage_input}.dfs.core.windows.net"
balanca_comercial_path = f"abfss://balancacomercial@{storage_input}.dfs.core.windows.net"

# %%
# Output Path
bronze_path = f"abfss://{container}@{storage_account}.dfs.core.windows.net/"
silver_path = f"abfss://{container_silver}@{storage_account}.dfs.core.windows.net/"
